# %% [markdown]
# <a href="https://colab.research.google.com/github/WenyiYao/cryptocurrency/blob/main/transformer_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow import keras
from keras import layers
import keras_nlp
from tensorflow.keras.callbacks import EarlyStopping
from keras.layers import TimeDistributed
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pandas as pd
import numpy as np
# Out:
# Using TensorFlow backend

# %%
df = pd.read_json('USDC-ETH.json')
df.head()
# Out:
#                                                  id         high          low  \
# 0  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19251  1483.170696  1396.900687
# 1  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19252  1476.144985  1402.098845
# 2  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19253  1469.421851  1324.864844
# 3  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19254  1392.051034  1274.907911
# 4  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19255  1383.911802  1313.997663
#
#          tvlUSD  txCount     volumeUSD       date         open    tick  \
# 0  2.517911e+08    11053  4.784684e+08 2022-09-16  1472.111248  203641
# 1  2.666791e+08     9014  2.088181e+08 2022-09-17  1433.463152  203394
# 2  2.485486e+08    10707  2.443570e+08 2022-09-18  1469.404359  204359
# 3  2.609486e+08    13410  3.697855e+08 2022-09-19  1334.321067  204053
# 4  2.540213e+08    11117  3.349061e+08 2022-09-20  1375.641442  204440
#
#          close
# 0  1433.463152
# 1  1469.404359
# 2  1334.321067
# 3  1375.641442
# 4  1322.192169

# %%
df = df.drop(columns=["id"])
df = df.set_index(['date'])
df.head()
# Out:
#                    high          low        tvlUSD  txCount     volumeUSD  \
# date
# 2022-09-16  1483.170696  1396.900687  2.517911e+08    11053  4.784684e+08
# 2022-09-17  1476.144985  1402.098845  2.666791e+08     9014  2.088181e+08
# 2022-09-18  1469.421851  1324.864844  2.485486e+08    10707  2.443570e+08
# 2022-09-19  1392.051034  1274.907911  2.609486e+08    13410  3.697855e+08
# 2022-09-20  1383.911802  1313.997663  2.540213e+08    11117  3.349061e+08
#
#                    open    tick        close
# date
# 2022-09-16  1472.111248  203641  1433.463152
# 2022-09-17  1433.463152  203394  1469.404359
# 2022-09-18  1469.404359  204359  1334.321067
# 2022-09-19  1334.321067  204053  1375.641442
# 2022-09-20  1375.641442  204440  1322.192169

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="a82b16dc-f7cd-4d24-a11d-933522815c9c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a82b16dc-f7cd-4d24-a11d-933522815c9c")) {                    Plotly.newPlot(                        "a82b16dc-f7cd-4d24-a11d-933522815c9c",                        [{"close":[1433.4631515261938,1469.4043591714062,1334.3210668168465,1375.6414418561278,1322.1921693346671,1246.55102393471,1326.5421050299713,1327.583336213949,1317.6350886948305,1294.1076624494317,1336.4113680454032,1328.6472894260633,1337.1102694696908,1336.4099210054073,1328.5729041814202,1311.1734032586453,1277.1549895567503,1323.7052233697948,1361.7440096520627,1352.6519479756146,1351.8952646433006,1331.5003840411457,1313.7694393196596,1322.8216538868974,1290.2031272583565,1279.2316046181018,1294.4066239494748,1287.4529240920535,1297.4054210153186,1274.2602752145647,1306.1004488475317,1331.319365021017,1310.2065158230241,1285.281206845382,1282.739321559561,1299.8858722609307,1313.5798969069112,1363.738888336176,1344.4204061845367,1461.3893785306252,1566.7331329892454,1513.4835217949903,1555.42222765187,1620.1519449697496,1590.5618353921284,1573.4780267799622,1591.971294388107,1519.1589205098126,1530.8637746777033,1645.1536476216352,1627.1376220164357,1568.8871735696648,1568.06546432969,1334.0539006

test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
sequence_length = 4
trainX, trainY = create_sequence(train, sequence_length)
testX, testY = create_sequence(test, sequence_length)

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (288, 4, 8)
# (288, 3)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], trainX.shape[2]))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], testX.shape[2]))

# %%
batch_size = 8
epochs=10

model1 = keras.Sequential([
    layers.Input(shape=(sequence_length, 8)),
    keras_nlp.layers.TransformerEncoder(num_heads=5, intermediate_dim=32),
    layers.GlobalAveragePooling1D(),
    layers.Dense(3) # output layer with 3 units for close, high and open value
])

model1.compile(loss='mean_squared_error', optimizer='adam')

#history = model1.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=2, shuffle=False)

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Lists to store training loss at the end of each iteration
training_loss = []
validation_loss = []

iterations = 14
epochs = 10

# Training loop
for iteration in range(iterations):
    print(f"Iteration {iteration + 1}/{iterations}")

    # Train the model with early stopping
    history = model1.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, validation_split=0.1,
                         verbose=2, shuffle=False, callbacks=[early_stopping])

    # Store the training loss at the end of each iteration
    #training_loss.extend(history.history['loss'])
    training_loss.extend([loss * 10000 for loss in history.history['loss']])
    #validation_loss.extend(history.history['val_loss'])
    validation_loss.extend([loss * 10000 for loss in history.history['val_loss']])
# Out:
# Iteration 1/14
# Epoch 1/10
# 33/33 - 5s - loss: 0.4542 - val_loss: 0.3488 - 5s/epoch - 152ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.1360 - val_loss: 0.1561 - 489ms/epoch - 15ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0797 - val_loss: 0.0909 - 262ms/epoch - 8ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0690 - val_loss: 0.0672 - 308ms/epoch - 9ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0577 - val_loss: 0.0534 - 310ms/epoch - 9ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0467 - val_loss: 0.0416 - 349ms/epoch - 11ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0356 - val_loss: 0.0286 - 341ms/epoch - 10ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0247 - val_loss: 0.0171 - 244ms/epoch - 7ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0163 - val_loss: 0.0099 - 305ms/epoch - 9ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0110 - val_loss: 0.0062 - 216ms/epoch - 7ms/step
# Iteration 2/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0081 - val_loss: 0.0047 - 303ms/epoch - 9ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0067 - val_loss: 0.0040 - 240ms/epoch - 7ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0060 - val_loss: 0.0038 - 286ms/epoch - 9ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0056 - val_loss: 0.0037 - 375ms/epoch - 11ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0054 - val_loss: 0.0036 - 348ms/epoch - 11ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0052 - val_loss: 0.0035 - 408ms/epoch - 12ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0050 - val_loss: 0.0034 - 351ms/epoch - 11ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0049 - val_loss: 0.0034 - 462ms/epoch - 14ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0047 - val_loss: 0.0033 - 316ms/epoch - 10ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0046 - val_loss: 0.0033 - 324ms/epoch - 10ms/step
# Iteration 3/14
# Epoch 1/10
# 33/33 - 1s - loss: 0.0045 - val_loss: 0.0032 - 632ms/epoch - 19ms/step
# Epoch 2/10
# 33/33 - 1s - loss: 0.0044 - val_loss: 0.0032 - 500ms/epoch - 15ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0044 - val_loss: 0.0031 - 217ms/epoch - 7ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0043 - val_loss: 0.0031 - 188ms/epoch - 6ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0042 - val_loss: 0.0031 - 276ms/epoch - 8ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0042 - val_loss: 0.0030 - 225ms/epoch - 7ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0041 - val_loss: 0.0030 - 296ms/epoch - 9ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0040 - val_loss: 0.0030 - 207ms/epoch - 6ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0040 - val_loss: 0.0030 - 215ms/epoch - 7ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0039 - val_loss: 0.0029 - 490ms/epoch - 15ms/step
# Iteration 4/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0039 - val_loss: 0.0029 - 444ms/epoch - 13ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0038 - val_loss: 0.0029 - 201ms/epoch - 6ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0038 - val_loss: 0.0029 - 236ms/epoch - 7ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0029 - 223ms/epoch - 7ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0028 - 206ms/epoch - 6ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0028 - 233ms/epoch - 7ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0036 - val_loss: 0.0028 - 226ms/epoch - 7ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0036 - val_loss: 0.0028 - 337ms/epoch - 10ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0036 - val_loss: 0.0028 - 314ms/epoch - 10ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0028 - 300ms/epoch - 9ms/step
# Iteration 5/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0027 - 195ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0027 - 130ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0027 - 131ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0027 - 132ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0034 - val_loss: 0.0027 - 131ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0034 - val_loss: 0.0027 - 116ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0034 - val_loss: 0.0027 - 122ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0033 - val_loss: 0.0027 - 119ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0033 - val_loss: 0.0027 - 113ms/epoch - 3ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0027 - 119ms/epoch - 4ms/step
# Iteration 6/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0027 - 246ms/epoch - 7ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 181ms/epoch - 5ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 193ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 228ms/epoch - 7ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 184ms/epoch - 6ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 177ms/epoch - 5ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 190ms/epoch - 6ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 164ms/epoch - 5ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 176ms/epoch - 5ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 174ms/epoch - 5ms/step
# Iteration 7/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 194ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 139ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 121ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 121ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 123ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 145ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 138ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 114ms/epoch - 3ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 134ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 132ms/epoch - 4ms/step
# Iteration 8/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 183ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 123ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 135ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0025 - 136ms/epoch - 4ms/step
# Iteration 9/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 200ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0026 - 115ms/epoch - 3ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0025 - 132ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0025 - 135ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0026 - 115ms/epoch - 3ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0026 - 123ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 131ms/epoch - 4ms/step
# Iteration 10/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0026 - 171ms/epoch - 5ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 129ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 136ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 126ms/epoch - 4ms/step
# Iteration 11/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 185ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0028 - 141ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 131ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 142ms/epoch - 4ms/step
# Iteration 12/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0028 - 199ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0028 - 130ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0027 - 128ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 142ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0027 - 129ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0028 - 140ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0029 - 132ms/epoch - 4ms/step
# Iteration 13/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0028 - 180ms/epoch - 5ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0029 - 120ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0030 - 155ms/epoch - 5ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0030 - 132ms/epoch - 4ms/step
# Iteration 14/14
# Epoch 1/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0029 - 192ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0030 - 126ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0031 - 163ms/epoch - 5ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0032 - 139ms/epoch - 4ms/step

# %%
model1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  transformer_encoder (Trans  (None, 4, 8)              767
#  formerEncoder)
#
#  global_average_pooling1d (  (None, 8)                 0
#  GlobalAveragePooling1D)
#
#  dense (Dense)               (None, 3)                 27
#
# =================================================================
# Total params: 794 (3.10 KB)
# Trainable params: 794 (3.10 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Plot training and validation loss
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
trainPredict = model1.predict(trainX, batch_size=batch_size)
trainScore = math.sqrt(mean_squared_error(trainY[:, 0], trainPredict[:, 0]))
print('Train Score of high value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainY[:, 1], trainPredict[:, 1]))
print('Train Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainY[:, 2], trainPredict[:, 2]))
print('Train Score of close value: %.10f RMSE' % (trainScore))
# Out:
# 36/36 [==============================] - 0s 2ms/step
# Train Score of high value: 0.0808932825 RMSE
# Train Score of low value: 0.0664205421 RMSE
# Train Score of close value: 0.1034030764 RMSE

# %%
testPredict = model1.predict(testX, batch_size=batch_size)
testScore = math.sqrt(mean_squared_error(testY[:, 0], testPredict[:, 0]))
print('Test Score of high value: %.10f RMSE' % (testScore))
trainScore = math.sqrt(mean_squared_error(testY[:, 1], testPredict[:, 1]))
print('Test Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(testY[:, 2], testPredict[:, 2]))
print('Test Score of close value: %.10f RMSE' % (trainScore))
# Out:
# 16/16 [==============================] - 0s 2ms/step
# Test Score of high value: 0.0820442984 RMSE
# Test Score of low value: 0.0409118840 RMSE
# Test Score of close value: 0.0564869705 RMSE

# %%
print(trainPredict.shape)
print(trainY.shape)
# Out:
# (288, 3)
# (288, 3)

# %%
print(testPredict.shape)
print(testY.shape)
# Out:
# (121, 3)
# (121, 3)

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 0], label=("Predicted High"))
plt.plot(testY[:, 0], label=("Actual High"))
plt.title('Original high vs predicted high', fontsize=15)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 1], label=("Predicted Low"))
plt.plot(testY[:, 1],label=("Actual Low"))
plt.title('Original low vs predicted low', fontsize=15)
plt.legend()
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 2], label=("Predicted Close"))
plt.plot(testY[:, 2], label=("Actual Close"))
plt.title('Original close vs predicted close', fontsize=15)
plt.legend()
plt.show()

# %%
date_index = train_size
plt.figure(figsize=(20, 10))
plt.plot(dataset[:,0], color = 'black', label = 'High Price')
plt.plot(range(date_index, date_index + len(testPredict)), testPredict[:, 0], color = 'green', label = 'Predicted High Price')
plt.title('USDC-ETH Price Prediction')
plt.xlabel('Time')
plt.ylabel('USDC-ETH Price')
plt.legend()
plt.show()
