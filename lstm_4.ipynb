# %% [markdown]
# <a href="https://colab.research.google.com/github/WenyiYao/cryptocurrency/blob/main/lstm_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_json('USDC-ETH.json')
df.head()
# Out:
#                                                  id         high          low  \
# 0  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19251  1483.170696  1396.900687
# 1  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19252  1476.144985  1402.098845
# 2  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19253  1469.421851  1324.864844
# 3  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19254  1392.051034  1274.907911
# 4  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19255  1383.911802  1313.997663
#
#          tvlUSD  txCount     volumeUSD       date         open    tick  \
# 0  2.517911e+08    11053  4.784684e+08 2022-09-16  1472.111248  203641
# 1  2.666791e+08     9014  2.088181e+08 2022-09-17  1433.463152  203394
# 2  2.485486e+08    10707  2.443570e+08 2022-09-18  1469.404359  204359
# 3  2.609486e+08    13410  3.697855e+08 2022-09-19  1334.321067  204053
# 4  2.540213e+08    11117  3.349061e+08 2022-09-20  1375.641442  204440
#
#          close
# 0  1433.463152
# 1  1469.404359
# 2  1334.321067
# 3  1375.641442
# 4  1322.192169

# %%
df = df.drop(columns=["id"])
df = df.set_index(['date'])
df.head()
# Out:
#                    high          low        tvlUSD  txCount     volumeUSD  \
# date
# 2022-09-16  1483.170696  1396.900687  2.517911e+08    11053  4.784684e+08
# 2022-09-17  1476.144985  1402.098845  2.666791e+08     9014  2.088181e+08
# 2022-09-18  1469.421851  1324.864844  2.485486e+08    10707  2.443570e+08
# 2022-09-19  1392.051034  1274.907911  2.609486e+08    13410  3.697855e+08
# 2022-09-20  1383.911802  1313.997663  2.540213e+08    11117  3.349061e+08
#
#                    open    tick        close
# date
# 2022-09-16  1472.111248  203641  1433.463152
# 2022-09-17  1433.463152  203394  1469.404359
# 2022-09-18  1469.404359  204359  1334.321067
# 2022-09-19  1334.321067  204053  1375.641442
# 2022-09-20  1375.641442  204440  1322.192169

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="350e60e9-a9ed-46a5-b57e-c7205f0c6932" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("350e60e9-a9ed-46a5-b57e-c7205f0c6932")) {                    Plotly.newPlot(                        "350e60e9-a9ed-46a5-b57e-c7205f0c6932",                        [{"close":[1433.4631515261938,1469.4043591714062,1334.3210668168465,1375.6414418561278,1322.1921693346671,1246.55102393471,1326.5421050299713,1327.583336213949,1317.6350886948305,1294.1076624494317,1336.4113680454032,1328.6472894260633,1337.1102694696908,1336.4099210054073,1328.5729041814202,1311.1734032586453,1277.1549895567503,1323.7052233697948,1361.7440096520627,1352.6519479756146,1351.8952646433006,1331.5003840411457,1313.7694393196596,1322.8216538868974,1290.2031272583565,1279.2316046181018,1294.4066239494748,1287.4529240920535,1297.4054210153186,1274.2602752145647,1306.1004488475317,1331.319365021017,1310.2065158230241,1285.281206845382,1282.739321559561,1299.8858722609307,1313.5798969069112,1363.738888336176,1344.4204061845367,1461.3893785306252,1566.7331329892454,1513.4835217949903,1555.42222765187,1620.1519449697496,1590.5618353921284,1573.4780267799622,1591.971294388107,1519.1589205098126,1530.8637746777033,1645.1536476216352,1627.1376220164357,1568.8871735696648,1568.06546432969,1334.0539006347674,1099.7250423266798,1295.2874897779468,1285.9885783807204,1254.1605236734401,1219.872643757742,1240.977833496094,1251.6326615959865,1215.355072058014,1198.9528155974276,1211.932477767782,1216.844597378877,1140.497107701902,1106.9685382555838,1137.5441785477537,1184.0581088713423,1203.2721213544762,1197.9486615411665,1204.966554427664,1191.450950382376,1167.9403772760775,1216.0354394400479,1294.849159093892,1275.4826876853265,1295.089709459369,1241.186876042802,1280.1689393920913,1259.809025631571,1271.5328608398438,1231.5059002599965,1280.5640123831436,1262.2799212646487,1265.9022980736208,1263.2121073091614,1275.3802545937278,1320.7311254347321,1307.5027413309017,1266.1248641580603,1167.4993961403661,1186.9491040388393,1183.0350138245346,1167.093919309262,1217.4099385436036,1214.0059941202448,1217.2907096120778,1219.9536761853683,1220.930623564374,1218.309494251504,1227.4594266044267,1211.4765187625133,1189.569392826188,1200.6814904704147,1198.8253243820861,1195.5839948533555,1199.7817218216985,1213.6934249197689,1214.1442907974645,1256.0588481926563,1250.2496519046645,1269.0408301069056,1263.5329225350383,1289.0454396406665,1321.008788470793,1335.4333965009832,1389.5776650297291,1416.5449361980109,1451.255874502207,1550.441081755956,1552.7026089664344,1576.5237832552575,1565.1380823831123,1511.320835491202,1551.9401641154145,1659.544375465029,1626.0195057179221,1627.8464443270461,1626.820921735898,1554.721374912468,1614.8008505438047,1602.0401028136987,1597.6280106294612,1573.1607760778131,1645.6284729740908,1566.2536801178408,1586.1482626723703,1641.7269365604143,1643.5995223893378,1664.668230487312,1666.9482495898603,1630.215818804121,1613.872987164238,1672.8381771616803,1649.997123304495,1544.5466983885813,1513.3415200931197,1538.9987372508062,1515.5027535611339,1506.8547671533242,1557.485008964664,1676.1683370999685,1638.6054532408596,1694.5673955731736,1692.6068638576864,1681.052007085757,1704.0300491381224,1659.0078348130544,1643.8449300762518,1650.6081582444288,1608.2849476252509,1595.3486289827017,1641.3506104032035,1634.0423194806447,1604.5035931017792,1665.2294039414182,1647.248931393667,1568.6024368769338,1566.2963366022998,1564.4861931700425,1566.0352565045746,1562.0752375775428,1531.8501400016369,1436.3981495770015,1439.4676224535228,1537.219889222437,1603.9502889819407,1680.2262756174057,1705.8679833675153,1655.246315878678,1677.7580484544183,1791.9787060 ...

# %%
dataset = df.values
dataset
# Out:
# array([[1.48317070e+03, 1.39690069e+03, 2.51791059e+08, ...,
#         1.47211125e+03, 2.03641000e+05, 1.43346315e+03],
#        [1.47614498e+03, 1.40209885e+03, 2.66679134e+08, ...,
#         1.43346315e+03, 2.03394000e+05, 1.46940436e+03],
#        [1.46942185e+03, 1.32486484e+03, 2.48548636e+08, ...,
#         1.46940436e+03, 2.04359000e+05, 1.33432107e+03],
#        ...,
#        [1.91744262e+03, 1.87164646e+03, 4.21586684e+08, ...,
#         1.89410228e+03, 2.00821000e+05, 1.90038819e+03],
#        [1.90651873e+03, 1.85254812e+03, 4.21238435e+08, ...,
#         1.90038819e+03, 2.00893000e+05, 1.88681227e+03],
#        [1.90372155e+03, 1.87535372e+03, 4.25635507e+08, ...,
#         1.88681227e+03, 2.00841000e+05, 0.00000000e+00]])

# %%
dataset.shape
# Out:
# (419, 8)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i+1:(i+look_back+1),[0,1,7]]) #predict high, low, and close
    return numpy.array(dataX), numpy.array(dataY)

# %%
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back = 4
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (288, 4, 8)
# (288, 4, 3)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], trainX.shape[2]))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], testX.shape[2]))

# %%
batch_size = 8
model0 = Sequential()
model0.add(LSTM(6, batch_input_shape=(batch_size, look_back, 8), stateful=True, return_sequences=True))
model0.add(TimeDistributed(Dense(3)))
model0.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Create a separate validation set
validation_size = int(len(trainX) * 0.1)
validation_size = (validation_size // batch_size) * batch_size
validationX, validationY = trainX[-validation_size:], trainY[-validation_size:]
trainX = trainX[:-validation_size]
trainY = trainY[:-validation_size]

for i in range(25):
    history = model0.fit(trainX, trainY, epochs=10, batch_size=batch_size, validation_data=(validationX, validationY),
                         verbose=2, shuffle=False, callbacks=[early_stopping])
    model0.reset_states()

    # Evaluate the model on the test set and store the test loss
    test_loss = model0.evaluate(testX, testY, batch_size=batch_size)

    # Draw the test loss
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.axhline(y=test_loss, color='r', linestyle='--', label='Test Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
# Out:
# Epoch 1/10
# 33/33 - 6s - loss: 0.1613 - val_loss: 0.2547 - 6s/epoch - 172ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0806 - val_loss: 0.1101 - 360ms/epoch - 11ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0583 - val_loss: 0.0603 - 316ms/epoch - 10ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0458 - val_loss: 0.0415 - 219ms/epoch - 7ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0374 - val_loss: 0.0309 - 256ms/epoch - 8ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0312 - val_loss: 0.0236 - 316ms/epoch - 10ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0264 - val_loss: 0.0182 - 261ms/epoch - 8ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0224 - val_loss: 0.0138 - 251ms/epoch - 8ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0192 - val_loss: 0.0103 - 224ms/epoch - 7ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0166 - val_loss: 0.0077 - 228ms/epoch - 7ms/step
# 16/16 [==============================] - 4s 14ms/step - loss: 0.0280
# Epoch 1/10
# 33/33 - 0s - loss: 0.0141 - val_loss: 0.0058 - 495ms/epoch - 15ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0131 - val_loss: 0.0047 - 248ms/epoch - 8ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0121 - val_loss: 0.0041 - 378ms/epoch - 11ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0113 - val_loss: 0.0039 - 455ms/epoch - 14ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0108 - val_loss: 0.0039 - 398ms/epoch - 12ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0103 - val_loss: 0.0040 - 384ms/epoch - 12ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0099 - val_loss: 0.0041 - 451ms/epoch - 14ms/step
# 16/16 [==============================] - 0s 8ms/step - loss: 0.0204
# Epoch 1/10
# 33/33 - 0s - loss: 0.0103 - val_loss: 0.0039 - 259ms/epoch - 8ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0103 - val_loss: 0.0040 - 232ms/epoch - 7ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0099 - val_loss: 0.0041 - 388ms/epoch - 12ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0095 - val_loss: 0.0041 - 425ms/epoch - 13ms/step
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0195
# Epoch 1/10
# 33/33 - 1s - loss: 0.0099 - val_loss: 0.0040 - 551ms/epoch - 17ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0100 - val_loss: 0.0041 - 333ms/epoch - 10ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0095 - val_loss: 0.0041 - 464ms/epoch - 14ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0091 - val_loss: 0.0042 - 382ms/epoch - 12ms/step
# 16/16 [==============================] - 0s 9ms/step - loss: 0.0188
# Epoch 1/10
# 33/33 - 1s - loss: 0.0095 - val_loss: 0.0041 - 906ms/epoch - 27ms/step
# Epoch 2/10
# 33/33 - 1s - loss: 0.0096 - val_loss: 0.0041 - 705ms/epoch - 21ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0091 - val_loss: 0.0042 - 410ms/epoch - 12ms/step
# Epoch 4/10
# 33/33 - 1s - loss: 0.0087 - val_loss: 0.0041 - 542ms/epoch - 16ms/step
# 16/16 [==============================] - 0s 11ms/step - loss: 0.0182
# Epoch 1/10
# 33/33 - 1s - loss: 0.0091 - val_loss: 0.0042 - 815ms/epoch - 25ms/step
# Epoch 2/10
# 33/33 - 1s - loss: 0.0092 - val_loss: 0.0042 - 672ms/epoch - 20ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0087 - val_loss: 0.0042 - 308ms/epoch - 9ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0083 - val_loss: 0.0041 - 269ms/epoch - 8ms/step
# Epoch 5/10
# 33/33 - 1s - loss: 0.0079 - val_loss: 0.0041 - 603ms/epoch - 18ms/step
# Epoch 6/10
# 33/33 - 1s - loss: 0.0076 - val_loss: 0.0040 - 528ms/epoch - 16ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0072 - val_loss: 0.0040 - 444ms/epoch - 13ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0070 - val_loss: 0.0039 - 486ms/epoch - 15ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0067 - val_loss: 0.0039 - 488ms/epoch - 15ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0065 - val_loss: 0.0038 - 389ms/epoch - 12ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0141
# Epoch 1/10
# 33/33 - 0s - loss: 0.0060 - val_loss: 0.0038 - 280ms/epoch - 8ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0060 - val_loss: 0.0037 - 310ms/epoch - 9ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0058 - val_loss: 0.0037 - 324ms/epoch - 10ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0057 - val_loss: 0.0037 - 279ms/epoch - 8ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0055 - val_loss: 0.0036 - 395ms/epoch - 12ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0053 - val_loss: 0.0036 - 281ms/epoch - 9ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0052 - val_loss: 0.0036 - 443ms/epoch - 13ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0051 - val_loss: 0.0035 - 434ms/epoch - 13ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0049 - val_loss: 0.0035 - 448ms/epoch - 14ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0048 - val_loss: 0.0035 - 430ms/epoch - 13ms/step
# 16/16 [==============================] - 0s 7ms/step - loss: 0.0117
# Epoch 1/10
# 33/33 - 0s - loss: 0.0046 - val_loss: 0.0034 - 307ms/epoch - 9ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0046 - val_loss: 0.0034 - 247ms/epoch - 7ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0045 - val_loss: 0.0034 - 212ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0044 - val_loss: 0.0033 - 141ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0043 - val_loss: 0.0033 - 138ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0042 - val_loss: 0.0033 - 121ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0041 - val_loss: 0.0033 - 122ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0040 - val_loss: 0.0032 - 138ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0040 - val_loss: 0.0032 - 120ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0039 - val_loss: 0.0032 - 198ms/epoch - 6ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0100
# Epoch 1/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0031 - 248ms/epoch - 8ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0031 - 183ms/epoch - 6ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0037 - val_loss: 0.0031 - 199ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0036 - val_loss: 0.0031 - 190ms/epoch - 6ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0036 - val_loss: 0.0030 - 176ms/epoch - 5ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0035 - val_loss: 0.0030 - 181ms/epoch - 5ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0034 - val_loss: 0.0030 - 195ms/epoch - 6ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0034 - val_loss: 0.0029 - 165ms/epoch - 5ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0033 - val_loss: 0.0029 - 198ms/epoch - 6ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0033 - val_loss: 0.0029 - 197ms/epoch - 6ms/step
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0088
# Epoch 1/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0029 - 252ms/epoch - 8ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0032 - val_loss: 0.0028 - 204ms/epoch - 6ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0028 - 125ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0028 - 139ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0031 - val_loss: 0.0028 - 123ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 156ms/epoch - 5ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0030 - val_loss: 0.0027 - 131ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0027 - 136ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 136ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0029 - val_loss: 0.0026 - 119ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0078
# Epoch 1/10
# 33/33 - 0s - loss: 0.0028 - val_loss: 0.0026 - 209ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0028 - val_loss: 0.0026 - 143ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0028 - val_loss: 0.0025 - 154ms/epoch - 5ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0027 - val_loss: 0.0025 - 136ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0027 - val_loss: 0.0025 - 127ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0027 - val_loss: 0.0025 - 130ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0026 - val_loss: 0.0024 - 123ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0026 - val_loss: 0.0024 - 118ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0026 - val_loss: 0.0024 - 136ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0026 - val_loss: 0.0024 - 141ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 1/10
# 33/33 - 0s - loss: 0.0025 - val_loss: 0.0023 - 179ms/epoch - 5ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0025 - val_loss: 0.0023 - 127ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0025 - val_loss: 0.0023 - 129ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0024 - val_loss: 0.0023 - 141ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0024 - val_loss: 0.0023 - 135ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0024 - val_loss: 0.0022 - 133ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0024 - val_loss: 0.0022 - 145ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0024 - val_loss: 0.0022 - 135ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0023 - val_loss: 0.0022 - 120ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0023 - val_loss: 0.0022 - 139ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0063
# Epoch 1/10
# 33/33 - 0s - loss: 0.0023 - val_loss: 0.0021 - 168ms/epoch - 5ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0023 - val_loss: 0.0021 - 133ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0023 - val_loss: 0.0021 - 126ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0022 - val_loss: 0.0021 - 111ms/epoch - 3ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0022 - val_loss: 0.0021 - 125ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0022 - val_loss: 0.0020 - 141ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0022 - val_loss: 0.0020 - 123ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0022 - val_loss: 0.0020 - 144ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0020 - 120ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0020 - 140ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 1/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0019 - 187ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0019 - 144ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0019 - 131ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0019 - 139ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0021 - val_loss: 0.0019 - 141ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0019 - 121ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 143ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 124ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 124ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 141ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0052
# Epoch 1/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 246ms/epoch - 7ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 183ms/epoch - 6ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0020 - val_loss: 0.0018 - 191ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 199ms/epoch - 6ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 181ms/epoch - 5ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 193ms/epoch - 6ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 174ms/epoch - 5ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 179ms/epoch - 5ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 208ms/epoch - 6ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0017 - 186ms/epoch - 6ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 1/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0016 - 265ms/epoch - 8ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0019 - val_loss: 0.0016 - 146ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 136ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 124ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 137ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 142ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 134ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 133ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0016 - 134ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 145ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 1/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 179ms/epoch - 5ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 136ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 151ms/epoch - 5ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 139ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0018 - val_loss: 0.0015 - 136ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0015 - 135ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0015 - 122ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0015 - 133ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0015 - 114ms/epoch - 3ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0015 - 126ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 1/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 183ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 151ms/epoch - 5ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 134ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 131ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 122ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 120ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 131ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 127ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 134ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 122ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 1/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 189ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 125ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 132ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0017 - val_loss: 0.0014 - 129ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0014 - 136ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 127ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 119ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 141ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 134ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 130ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0038
# Epoch 1/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 200ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 169ms/epoch - 5ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 159ms/epoch - 5ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 158ms/epoch - 5ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 156ms/epoch - 5ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 128ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 144ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 148ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 132ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 126ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0036
# Epoch 1/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 284ms/epoch - 9ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 208ms/epoch - 6ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 214ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 188ms/epoch - 6ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0013 - 203ms/epoch - 6ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 206ms/epoch - 6ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 211ms/epoch - 6ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 193ms/epoch - 6ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 209ms/epoch - 6ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 212ms/epoch - 6ms/step
# 16/16 [==============================] - 0s 4ms/step - loss: 0.0035
# Epoch 1/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 242ms/epoch - 7ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0016 - val_loss: 0.0012 - 179ms/epoch - 5ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 201ms/epoch - 6ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 192ms/epoch - 6ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 182ms/epoch - 6ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 177ms/epoch - 5ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 192ms/epoch - 6ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 128ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 143ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 144ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0033
# Epoch 1/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 189ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 126ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 137ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 144ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0012 - 136ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 123ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 144ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 139ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 138ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 129ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 1/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 182ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 133ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 145ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 138ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 141ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 128ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 136ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 125ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 159ms/epoch - 5ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 126ms/epoch - 4ms/step
# 16/16 [==============================] - 0s 3ms/step - loss: 0.0030
# Epoch 1/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 197ms/epoch - 6ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 124ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 143ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 166ms/epoch - 5ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 142ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 141ms/epoch - 4ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 127ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0011 - 135ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0010 - 151ms/epoch - 5ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0015 - val_loss: 0.0010 - 149ms/epoch - 5ms/step
# 16/16 [==============================] - 0s 2ms/step - loss: 0.0029

# %%
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (8, 4, 6)                 360
#
#  time_distributed (TimeDist  (8, 4, 3)                 21
#  ributed)
#
# =================================================================
# Total params: 381 (1.49 KB)
# Trainable params: 381 (1.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def calculate_metrics(true, predicted):
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(true, predicted)
    r2 = r2_score(true, predicted)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae, "R2": r2}

# high value metrics
testPredict = model0.predict(testX, batch_size=batch_size)
calculate_metrics(testY[:, -1, 0], testPredict[:testY.shape[0], -1, 0])
# Out:
# 16/16 [==============================] - 1s 3ms/step
# {'MSE': 0.0015367559860993117,
#  'RMSE': 0.03920147938661642,
#  'MAE': 0.034408338142178016,
#  'R2': 0.8960352797758401}

# %%
date_index = train_size
plt.figure(figsize=(20, 10))
plt.plot(dataset[:,0], color = 'black', label = 'High Price')
plt.plot(range(date_index, date_index + len(testPredict)), testPredict[:, -1, 0], color = 'green', label = 'Predicted High Price')
plt.title('USDC-ETH Price Prediction')
plt.xlabel('Time')
plt.ylabel('USDC-ETH Price')
plt.legend()
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], -1, 0])
plt.plot(testY[:, -1, 0])
plt.title('Original high vs predicted high', fontsize=15)
plt.show()

# %%
trainPredict = model0.predict(trainX, batch_size=batch_size)
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 0], trainPredict[:, -1, 0]))
print('Train Score of high value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 1], trainPredict[:, -1, 1]))
print('Train Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 2], trainPredict[:, -1, 2]))
print('Train Score of close value: %.10f RMSE' % (trainScore))
model0.reset_states()
# Out:
# 33/33 [==============================] - 0s 3ms/step
# Train Score of high value: 0.0238042647 RMSE
# Train Score of low value: 0.0232645573 RMSE
# Train Score of close value: 0.3300557877 RMSE

# %%
testPredict = model0.predict(testX, batch_size=batch_size)
testScore = math.sqrt(mean_squared_error(testY[:, -1, 0], testPredict[0:testY.shape[0], -1, 0]))
print('Test Score of high value: %.10f RMSE' % (testScore))
trainScore = math.sqrt(mean_squared_error(testY[:, -1, 1], testPredict[0:testY.shape[0], -1, 1]))
print('Test Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(testY[:, -1, 2], testPredict[0:testY.shape[0], -1, 2]))
print('Test Score of close value: %.10f RMSE' % (trainScore))
# Out:
# 16/16 [==============================] - 0s 3ms/step
# Test Score of high value: 0.0392730717 RMSE
# Test Score of low value: 0.0365675178 RMSE
# Test Score of close value: 0.0164354048 RMSE

# %%
print(trainPredict.shape)
print(trainY.shape)
# Out:
# (264, 4, 3)
# (264, 4, 3)

# %%
print(testPredict.shape)
print(testY.shape)
# Out:
# (128, 4, 3)
# (121, 4, 3)

# %%
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], -1, 1])
plt.plot(testY[:, -1, 1])
plt.title('Original low vs predicted low', fontsize=15)
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], -1, 2])
plt.plot(testY[:, -1, 2])
plt.title('Original close vs predicted close', fontsize=15)
plt.show()
