# %% [markdown]
# <a href="https://colab.research.google.com/github/WenyiYao/cryptocurrency/blob/main/transformer_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
import tensorflow as tf
from tensorflow import keras
from keras import layers
import keras_nlp
from keras.layers import TimeDistributed
from keras.layers import Dense
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_json('poolDayData_0.json')
df.head()
# Out:
#                                                  id      high       low  \
# 0  0x07a6e955ba4345bae83ac2a6faa771fddd8a2011-19251  0.787862  0.829892
# 1  0x07a6e955ba4345bae83ac2a6faa771fddd8a2011-19252  0.796931  0.829426
# 2  0x07a6e955ba4345bae83ac2a6faa771fddd8a2011-19253  0.756814  0.829987
# 3  0x07a6e955ba4345bae83ac2a6faa771fddd8a2011-19254  0.727532  0.778021
# 4  0x07a6e955ba4345bae83ac2a6faa771fddd8a2011-19255  0.722816  0.765373
#
#           tvlUSD  txCount     volumeUSD       date      open    tick     close
# 0  390558.121780       63  47603.628095 2022-09-16  0.825782 -278530  0.807040
# 1  391985.894464       43  25969.275749 2022-09-17  0.807040 -278202  0.824302
# 2  374113.451267       64  39271.628388 2022-09-18  0.824302 -279093  0.750910
# 3  377515.557429       97  74419.312606 2022-09-19  0.750910 -278972  0.765373
# 4  369165.264073       56  45400.579439 2022-09-20  0.765373 -279395  0.735607

# %%
df = df.drop(columns=["id"])
df = df.set_index(['date'])
df.head()
# Out:
#                 high       low         tvlUSD  txCount     volumeUSD  \
# date
# 2022-09-16  0.787862  0.829892  390558.121780       63  47603.628095
# 2022-09-17  0.796931  0.829426  391985.894464       43  25969.275749
# 2022-09-18  0.756814  0.829987  374113.451267       64  39271.628388
# 2022-09-19  0.727532  0.778021  377515.557429       97  74419.312606
# 2022-09-20  0.722816  0.765373  369165.264073       56  45400.579439
#
#                 open    tick     close
# date
# 2022-09-16  0.825782 -278530  0.807040
# 2022-09-17  0.807040 -278202  0.824302
# 2022-09-18  0.824302 -279093  0.750910
# 2022-09-19  0.750910 -278972  0.765373
# 2022-09-20  0.765373 -279395  0.735607

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="907d4e1d-2bdf-4769-ac40-ceb1bd6c58ee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("907d4e1d-2bdf-4769-ac40-ceb1bd6c58ee")) {                    Plotly.newPlot(                        "907d4e1d-2bdf-4769-ac40-ceb1bd6c58ee",                        [{"close":[0.8070400596001781,0.8243021851772071,0.7509098288385221,0.7653725757213821,0.7356071061743451,0.705214240735718,0.750366721671966,0.7801069429659581,0.755164690702651,0.74228890946692,0.752366241089497,0.73657972446843,0.750351678018733,0.7643146315896651,0.7759260120012941,0.7650338665948421,0.763461360029088,0.8063975997950481,0.8389772658760141,0.8611826322627331,0.8346365820069921,0.830159271824709,0.813103867807592,0.827605165379492,0.8137863778702861,0.791848515585263,0.7857973838891761,0.7809413393038691,0.79456843356493,0.7931209529272001,0.8003531119660461,0.8507882913125231,0.859550015935125,0.8445470590467381,0.7996344054950181,0.829407607936253,0.8307495646010791,0.9044167486975361,0.8959293704089301,0.924540316497325,0.937407884560101,0.8997989529160111,0.945219281708723,0.930143254640805,0.9077938724535841,0.9017896151961851,0.8807054583003191,0.868947471362242,0.9495248904585841,1.179313378781802,1.183635900713929,1.133128536664894,1.088831700608183,1.04453486455147,0.803313099491865,1.11802951023008,1.053162394668372,0.936992268396412,0.8856723979230811,0.921573582115741,0.9359251644741551,0.90257701310931,0.8738183233676331,0.8788612199152921,0.8737514784025051,0.802321989282188,0.8003429817357101,0.8503528659405991,0.866586069106542,0.8493445414323401,0.8419817525906941,0.846878737672316,0.8447796973874051,0.8167363855049281,0.8412738324233091,0.9390471661442971,0.9071608835593361,0.941980807645138,0.901623237905053,0.9211842266773981,0.9136953726745951,0.9163531603817531,0.8954119324847021,0.929390752594327,0.9108997732897881,0.9082286504971251,0.8942631880324261,0.911701555909268,0.9240302140027371,0.901703168874829,0.8828161174747601,0.797145887598518,0.8136341764386481,0.8137261126396651,0.772923841668397,0.794289305767086,0.794012981991505,0.794406322798414,0.797801754739699,0.801390097111712,0.792935222929768,0.8201836367021941,0.8023979498536621,0.7812372305817921,0.780732514737801,0.7639397577968811,0.7558082570548491,0.7562616612295371,0.7846397440018721,0.7769090302264791,0.8062984206224281,0.788540026995546,0.7993298919083821,0.8059785885739551,0.8400692216203891,0.843210479356683,0.8553511895704541,0.893412504284231,0.914998072001671,0.932925042819533,1.000560593529076,0.9929963441138301,1.013731288285501,0.9947282327401791,0.933714531334184,0.953760901876583,1.025893646641689,0.9836596578356731,0.9930413922458641,0.9970219206938451,0.9529695141538471,0.9994695946273531,1.125142491687543,1.154397286124538,1.149446404412772,1.1752090658171341,1.08577621691025,1.1104493704939151,1.205315711794713,1.186150824116807,1.241914325184438,1.251799881546269,1.210043327723899,1.193401657900723,1.2711134731540241,1.3038350465101871,1.222751660625828,1.2245380664584111,1.249070586267113,1.234581655525287,1.183647891961953,1.251924948158978,1.385692220364813,1.3842102800634821,1.432650426559055,1.481090573054628,1.485356586782272,1.467620860263232,1.377686592118188,1.397791951664654,1.350646828213946,1.263225257534976,1.240414817209778,1.274263954453502,1.230453516953281,1.194557523033244,1.248504195560261,1.218204073943008,1.166812888244848,1.135154387199838,1.13013001480152,1.130003666403456,1.146941346071516,1.05158132666739,1.009252323143183,1.072066756324786,1.087929557388577,1.165762737424896,1.198500313985114,1.197959252524685,1.122900347428897,1.148860843306329,1.226957774372615,1.17707445943206,1.169146208070658,1.120542292404396,1.153553 ...

# %%
dataset = df.values
dataset
# Out:
# array([[ 7.87862287e-01,  8.29892477e-01,  3.90558122e+05, ...,
#          8.25781924e-01, -2.78530000e+05,  8.07040060e-01],
#        [ 7.96930701e-01,  8.29426013e-01,  3.91985894e+05, ...,
#          8.07040060e-01, -2.78202000e+05,  8.24302185e-01],
#        [ 7.56813753e-01,  8.29986952e-01,  3.74113451e+05, ...,
#          8.24302185e-01, -2.79093000e+05,  7.50909829e-01],
#        ...,
#        [ 6.87838526e-01,  7.38167099e-01,  3.59513332e+05, ...,
#          6.94514893e-01, -2.79577000e+05,  7.25942301e-01],
#        [ 7.10644868e-01,  7.43249712e-01,  3.59720647e+05, ...,
#          7.25942301e-01, -2.79292000e+05,  7.60861060e-01],
#        [ 6.62648431e-01,  8.23300917e-01,  3.75465258e+05, ...,
#          7.60861060e-01, -2.78565000e+05,  0.00000000e+00]])

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
def create_sequence(dataset, sequence_length=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-sequence_length-1):
        a = dataset[i:(i+sequence_length)]
        dataX.append(a)
        dataY.append(dataset[i+sequence_length,[0,1,7]]) #predict high, low, and close
    return numpy.array(dataX), numpy.array(dataY)

# %%
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
sequence_length = 4
trainX, trainY = create_sequence(train, sequence_length)
testX, testY = create_sequence(test, sequence_length)

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (288, 4, 8)
# (288, 3)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], trainX.shape[2]))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], testX.shape[2]))

# %%
batch_size = 8
epochs=10

model1 = keras.Sequential([
    layers.Input(shape=(sequence_length, 8)),
    keras_nlp.layers.TransformerEncoder(num_heads=2, intermediate_dim=32),
    layers.GlobalAveragePooling1D(),
    layers.Dense(3) # output layer with 3 units for close, high and open value
])

model1.compile(loss='mean_squared_error', optimizer='adam')

history = model1.fit(trainX, trainY, epochs=epochs, batch_size=batch_size, validation_split=0.1, verbose=2, shuffle=False)
# Out:
# Epoch 1/10
# 33/33 - 3s - loss: 0.6357 - val_loss: 0.8306 - 3s/epoch - 80ms/step
# Epoch 2/10
# 33/33 - 0s - loss: 0.1078 - val_loss: 0.6966 - 132ms/epoch - 4ms/step
# Epoch 3/10
# 33/33 - 0s - loss: 0.0857 - val_loss: 0.5596 - 127ms/epoch - 4ms/step
# Epoch 4/10
# 33/33 - 0s - loss: 0.0717 - val_loss: 0.4526 - 123ms/epoch - 4ms/step
# Epoch 5/10
# 33/33 - 0s - loss: 0.0600 - val_loss: 0.3655 - 134ms/epoch - 4ms/step
# Epoch 6/10
# 33/33 - 0s - loss: 0.0499 - val_loss: 0.2949 - 158ms/epoch - 5ms/step
# Epoch 7/10
# 33/33 - 0s - loss: 0.0427 - val_loss: 0.2366 - 141ms/epoch - 4ms/step
# Epoch 8/10
# 33/33 - 0s - loss: 0.0378 - val_loss: 0.1890 - 123ms/epoch - 4ms/step
# Epoch 9/10
# 33/33 - 0s - loss: 0.0334 - val_loss: 0.1514 - 121ms/epoch - 4ms/step
# Epoch 10/10
# 33/33 - 0s - loss: 0.0299 - val_loss: 0.1201 - 119ms/epoch - 4ms/step

# %%
model1.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  transformer_encoder_7 (Tra  (None, 4, 8)              872
#  nsformerEncoder)
#
#  global_average_pooling1d_7  (None, 8)                 0
#   (GlobalAveragePooling1D)
#
#  dense_5 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 899 (3.51 KB)
# Trainable params: 899 (3.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
trainPredict = model1.predict(trainX, batch_size=batch_size)
trainScore = math.sqrt(mean_squared_error(trainY[:, 0], trainPredict[:, 0]))
print('Train Score of high value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainY[:, 1], trainPredict[:, 1]))
print('Train Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainY[:, 2], trainPredict[:, 2]))
print('Train Score of close value: %.10f RMSE' % (trainScore))
# Out:
# 36/36 [==============================] - 0s 2ms/step
# Train Score of high value: 0.1847612275 RMSE
# Train Score of low value: 0.2381201667 RMSE
# Train Score of close value: 0.0941335711 RMSE

# %%
testPredict = model1.predict(testX, batch_size=batch_size)
testScore = math.sqrt(mean_squared_error(testY[:, 0], testPredict[:, 0]))
print('Test Score of high value: %.2f RMSE' % (testScore))
trainScore = math.sqrt(mean_squared_error(testY[:, 1], testPredict[:, 1]))
print('Test Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(testY[:, 2], testPredict[:, 2]))
print('Test Score of close value: %.10f RMSE' % (trainScore))
# Out:
# 16/16 [==============================] - 0s 9ms/step
# Test Score of high value: 0.20 RMSE
# Test Score of low value: 0.3929993999 RMSE
# Test Score of close value: 0.0713899679 RMSE

# %%
print(trainPredict.shape)
print(trainY.shape)
# Out:
# (288, 3)
# (288, 3)

# %%
print(testPredict.shape)
print(testY.shape)
# Out:
# (121, 3)
# (121, 3)

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 0])
plt.plot(testY[:, 0])
plt.title('Original high vs predicted high', fontsize=15)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 1])
plt.plot(testY[:, 1])
plt.title('Original low vs predicted low', fontsize=15)
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 2])
plt.plot(testY[:, 2])
plt.title('Original close vs predicted close', fontsize=15)
plt.show()
